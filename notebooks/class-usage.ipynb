# %% [markdown]
# # CommentProcessor Class Usage

# %% [markdown]
# Execution of the comment analysis through the `CommentProcessor` class and plotting of results via `plot_results`.

# %%
import sys
sys.path.insert(0, '..')

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from src.comment_analysis.comment_processor import CommentProcessor
from src.comment_analysis.visualisation import plot_results

# %% [markdown]
# ## Raw HTML loading
#
# Note: populate `html_body.txt` with some real data before executing the next cell!

# %%
with open('./html_body.txt', 'r', encoding='utf-8') as file:
    raw_html = file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with open('./html_body.txt', 'r', encoding='utf-8') as file:
#       2     raw_html = file.read()
#
# File ~\Envs\yt-comment-testing-2\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './html_body.txt'

# %% [markdown]
# ## Processing of Data

# %%
cp = CommentProcessor()
cp
# Out:
# CommentProcessor(analyze_donations=True, target_currency='USD', translate_comments=True, translate_language_code='en', dislike_polarity_cutoff=0.5)

# %%
response_dict = cp.process_comments(raw_html=raw_html)
# Out:
# Translating comment concatenates: 100%|█| 13/13 [00:02<00:00,  4.52i
# Extracted 225 raw comments and successfully translated 221 of them.
# Comment polarity median: VADER: 0.64, TextBlob: 0.20
#
# Highly positive comments: 82, highly negative comments: 2, ratio positive/negative: 41.0
# Video likes: 314865
# Estimate of video dislikes based on likes and comment polarity: 7679
#
# Total sum of donations: 1826.49 USD

# %% [markdown]
# ## Plot Generation
#
# You can trigger the generation of word clouds via the corresponding argument.

# %%
plot_results(response_dict=response_dict,
             plot_word_cloud=False)
